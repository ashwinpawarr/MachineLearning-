# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/tv/top_rated?api_key=02d8423114d972759635b08b4e261b84&language=en-US&page=1")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Breaking Bad',
#    'overview': "Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'popularity': 91.4073,
#    'poster_path': '/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg',
#    'first_air_date': '2008-01-20',
#    'name': 'Breaking Bad',
#    'vote_average': 8.922,
#    'vote_count': 16195},
#   {'adult': False,
#    'backdrop_path': '/a9qlroMOHewiDsUR93PYMVfpbF5.jpg',
#    'genre_ids': [18],
#    'id': 219246,
#    'origin_country': ['KR'],
#    'original_language': 'ko',
# ...

# %%
pd.DataFrame(response.json()["results"])
# Out:
#     adult                     backdrop_path  \
# 0   False  /tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg
# 1   False  /a9qlroMOHewiDsUR93PYMVfpbF5.jpg
# 2   False  /sYXLeu5usz6yEz0k00FYvtEdodD.jpg
# 3   False  /kU98MbVVgi72wzceyrEbClZmMFe.jpg
# 4   False  /emGCHnRPru5LLWcKbSFzUEUisac.jpg
# 5   False  /4Mt7WHox67uJ1yErwTBFcV8KWgG.jpg
# 6   False  /A6tMQAo6t6eRFCPhsrShmxZLqFB.jpg
# 7   False  /3siv3RaQrdr2tQiv9jHq71sLlzo.jpg
# 8   False  /hPea3Qy5Gd6z4kJLUruBbwAH8Rm.jpg
# 9   False  /uL6Ad12W09L1sfuOE2pcTeak7bt.jpg
# 10  False  /Ao5pBFuWY32cVuh6iYjEjZMEscN.jpg
# 11  False  /gffVOVZ2Y9cmVIZ26Gt9ByMGCYH.jpg
# 12  False  /toP4wdAiIxOmfqcygXsKtjtr2Rd.jpg
# 13  False  /rqbCbjB19amtOtFQbb3K2lgm2zv.jpg
# 14  False  /mGHrUSt2uA5RaIheSmBfRnRHPS8.jpg
# 15  False  /6U0e6OHklJAcMAuIoGXjTBS5zsI.jpg
# 16  False  /ywQtHG17LZhAFZyZtBflhtFMtJ7.jpg
# 17  False  /oQ3xEgcqlb6RufhCg3I3tsa0FET.jpg
# 18  False  /lNpkvX2s8LGB0mjGODMT4o6Up7j.jpg
# 19  False  /5bNQtKzufiAbwUpU1jWDwUIOVlm.jpg
#
# ...

# %%
pd.DataFrame(response.json()["results"])[["id","overview","adult","genre_ids"]]
# Out:
#         id                                           overview  adult  \
# 0     1396  Walter White, a New Mexico chemistry teacher, ...  False
# 1   219246  In Jeju, a spirited girl and a steadfast boy's...  False
# 2    94605  Amid the stark discord of twin cities Piltover...  False
# 3      246  In a war-torn world of elemental magic, a youn...  False
# 4   209867  Decades after her party defeated the Demon Kin...  False
# 5    37854  Years ago, the fearsome Pirate King, Gol D. Ro...  False
# 6    31911  Disregard for alchemy’s laws ripped half of Ed...  False
# 7    85077  The life of Christ through the eyes of those w...  False
# 8    60059  Six years before Saul Goodman meets Walter Whi...  False
# 9    87108  The true story of one of the worst man-made ca...  False
# 10   60625  Rick is a mentally-unbalanced but scientifical...  False
# 11  220542  Maomao lived a peaceful life with her apotheca...  False
# 12   94954  In attempt to find a non-violent alternative f...  False
# ...

# %%
pd.DataFrame(response.json()["results"]).head(3)
# Out:
#    adult                     backdrop_path               genre_ids      id  \
# 0  False  /tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg                [18, 80]    1396
# 1  False  /a9qlroMOHewiDsUR93PYMVfpbF5.jpg                    [18]  219246
# 2  False  /sYXLeu5usz6yEz0k00FYvtEdodD.jpg  [16, 10765, 18, 10759]   94605
#
#   origin_country original_language original_name  \
# 0           [US]                en  Breaking Bad
# 1           [KR]                ko       폭싹 속았수다
# 2           [US]                en        Arcane
#
#                                             overview  popularity  \
# 0  Walter White, a New Mexico chemistry teacher, ...     91.4073
# 1  In Jeju, a spirited girl and a steadfast boy's...     16.3254
# 2  Amid the stark discord of twin cities Piltover...     23.2559
#
#                         poster_path first_air_date  \
# 0  /ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg     2008-01-20
# 1  /q29q6AByug53pnylCytwLA7m6AY.jpg     2025-03-07
# ...

# %%
df = pd.DataFrame

# %%
df
# Out:
# pandas.core.frame.DataFrame
